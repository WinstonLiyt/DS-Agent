# %%
# !pip install gdown
# Out:
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# ...

# %%
import gdown

url = 'https://drive.google.com/uc?id=1xUd1nvCsMLfe-mv9NBBHOAtuYnSMgBGx'
output = 'benchmarks.zip'  # Change this to the preferred path and file name
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1xUd1nvCsMLfe-mv9NBBHOAtuYnSMgBGx
# From (redirected): https://drive.google.com/uc?id=1xUd1nvCsMLfe-mv9NBBHOAtuYnSMgBGx&confirm=t&uuid=0770f80d-8b8f-4fa4-ae3b-dc33690d4a3c
# To: /data/userdata/v-taozhiwang/DS-Agent/benchmarks.zip
# 100%|██████████| 153M/153M [00:03<00:00, 41.7MB/s]
# 'benchmarks.zip'

# %%
# !unzip development/benchmarks.zip -d development/benchmarks/
# !unzip development/data.zip -d development/data/
# Out:
# Archive:  development/benchmarks.zip
#    creating: development/benchmarks/airline-reviews/
#    creating: development/benchmarks/airline-reviews/env/
#    creating: development/benchmarks/airline-reviews/env/__pycache__/
#   inflating: development/benchmarks/airline-reviews/env/__pycache__/submission.cpython-310.pyc
#   inflating: development/benchmarks/airline-reviews/env/submission.py
#   inflating: development/benchmarks/airline-reviews/env/test.csv
#   inflating: development/benchmarks/airline-reviews/env/train.csv
#   inflating: development/benchmarks/airline-reviews/env/train.py
#    creating: development/benchmarks/airline-reviews/scripts/
#   inflating: development/benchmarks/airline-reviews/scripts/prepared
#   inflating: development/benchmarks/airline-reviews/scripts/research_problem.txt
#    creating: development/benchmarks/bitcoin-price-prediction/
#    creating: development/benchmarks/bitcoin-price-prediction/env/
# ...
